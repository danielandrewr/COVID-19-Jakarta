# %%
# Analysis done by Runtime Error
# Compfest Data Science Academy Test

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('./Dataset Analisis.xlsx')
df2 = pd.read_excel('./Dataset Analisis2.xlsx')

# %%
df.corr()
# Out:
#                 Meninggal  Vaksinasi 2  Positif Harian
# Meninggal        1.000000     0.848992        0.861486
# Vaksinasi 2      0.848992     1.000000        0.496749
# Positif Harian   0.861486     0.496749        1.000000

# %%
x_ = df['Tanggal']
y_ = df['Meninggal']
y2_ = df['Vaksinasi 2']
z_ = df["Positif Harian"]

# %%
plt.figure(figsize=(16, 6))
sns.scatterplot(data=df, x=x_, y=y_)
# Out:
# <AxesSubplot:xlabel='Tanggal', ylabel='Meninggal'>

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(data=df, x=x_, y=y2_)
# Out:
# <AxesSubplot:xlabel='Tanggal', ylabel='Vaksinasi 2'>

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(data=df, x=x_, y=z_)
# Out:
# <AxesSubplot:xlabel='Tanggal', ylabel='Positif Harian'>

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=df, x=y2_, y=z_)
# Out:
# <AxesSubplot:xlabel='Vaksinasi 2', ylabel='Positif Harian'>
